# %% [markdown]
# ### Data Science vs. Business Intelligence / Data Analytics
#
# * Data analytics/BI focuses on understanding datasets and extracting insights for actionable decisions.
# * Data science involves building, cleaning, and organizing datasets, and creating predictive models.
# * Data analysts have a more narrow and specialized role, while data scientists ask broader, strategic questions.
# *  BI is focused on extracting actionable insights from data and presenting those to stakeholders

# %%
! pip install geopandas
! pip install geoplot
# Out:
# Requirement already satisfied: geopandas in c:\users\yehtu\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas) (0.9.0)
# Requirement already satisfied: packaging in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\yehtu\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yehtu\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: certifi in c:\users\yehtu\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\yehtu\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: geoplot in c:\users\yehtu\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: matplotlib>=3.1.2 in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (3.8.0)
# Requirement already satisfied: seaborn in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (0.12.2)
# Requirement already satisfied: pandas in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (1.5.3)
# Requirement already satisfied: geopandas>=0.9.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (1.0.1)
# Requirement already satisfied: cartopy in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (0.23.0)
# Requirement already satisfied: mapclassify>=2.1 in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (2.8.0)
# Requirement already satisfied: contextily>=1.0.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geoplot) (1.6.2)
# Requirement already satisfied: geopy in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (2.4.1)
# Requirement already satisfied: mercantile in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (1.2.1)
# Requirement already satisfied: pillow in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (10.2.0)
# Requirement already satisfied: rasterio in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (1.3.11)
# Requirement already satisfied: requests in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (2.31.0)
# Requirement already satisfied: joblib in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (1.2.0)
# Requirement already satisfied: xyzservices in c:\users\yehtu\anaconda3\lib\site-packages (from contextily>=1.0.0->geoplot) (2022.9.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas>=0.9.0->geoplot) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas>=0.9.0->geoplot) (0.9.0)
# Requirement already satisfied: packaging in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas>=0.9.0->geoplot) (23.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas>=0.9.0->geoplot) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\yehtu\anaconda3\lib\site-packages (from geopandas>=0.9.0->geoplot) (2.0.6)
# Requirement already satisfied: networkx>=2.7 in c:\users\yehtu\anaconda3\lib\site-packages (from mapclassify>=2.1->geoplot) (3.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\yehtu\anaconda3\lib\site-packages (from mapclassify>=2.1->geoplot) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in c:\users\yehtu\anaconda3\lib\site-packages (from mapclassify>=2.1->geoplot) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yehtu\anaconda3\lib\site-packages (from matplotlib>=3.1.2->geoplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yehtu\anaconda3\lib\site-packages (from matplotlib>=3.1.2->geoplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yehtu\anaconda3\lib\site-packages (from matplotlib>=3.1.2->geoplot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yehtu\anaconda3\lib\site-packages (from matplotlib>=3.1.2->geoplot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yehtu\anaconda3\lib\site-packages (from matplotlib>=3.1.2->geoplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yehtu\anaconda3\lib\site-packages (from matplotlib>=3.1.2->geoplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yehtu\anaconda3\lib\site-packages (from pandas->geoplot) (2023.3.post1)
# Requirement already satisfied: pyshp>=2.3 in c:\users\yehtu\anaconda3\lib\site-packages (from cartopy->geoplot) (2.3.1)
# Requirement already satisfied: certifi in c:\users\yehtu\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas>=0.9.0->geoplot) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\yehtu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->geoplot) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yehtu\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify>=2.1->geoplot) (2.2.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\yehtu\anaconda3\lib\site-packages (from geopy->contextily>=1.0.0->geoplot) (2.0)
# Requirement already satisfied: click>=3.0 in c:\users\yehtu\anaconda3\lib\site-packages (from mercantile->contextily>=1.0.0->geoplot) (8.1.7)
# Requirement already satisfied: affine in c:\users\yehtu\anaconda3\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (2.4.0)
# Requirement already satisfied: attrs in c:\users\yehtu\anaconda3\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (23.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\yehtu\anaconda3\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\yehtu\anaconda3\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\yehtu\anaconda3\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\yehtu\anaconda3\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (68.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yehtu\anaconda3\lib\site-packages (from requests->contextily>=1.0.0->geoplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yehtu\anaconda3\lib\site-packages (from requests->contextily>=1.0.0->geoplot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yehtu\anaconda3\lib\site-packages (from requests->contextily>=1.0.0->geoplot) (2.0.7)
# Requirement already satisfied: colorama in c:\users\yehtu\anaconda3\lib\site-packages (from click>=3.0->mercantile->contextily>=1.0.0->geoplot) (0.4.6)

# %%
# install geopandas and geoplot:
# conda install geopandas
# conda install -c conda-forge geoplot
import geopandas
import geoplot
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
# Lets find the most exensive type of rooms. 

df = pd.read_csv('data/listings_ZD.csv')

dfrm = df.groupby('room_type')['price'].mean()
dfrm.reset_index()
dfrm.plot(kind='bar', x='room_type', y='price')
# Out:
# <Axes: xlabel='room_type'>

# %%
dfrm.plot(kind='barh', x='room_type', y='price')
# Out:
# <Axes: ylabel='room_type'>

# %%
df = pd.read_csv('data/listings_ZD.csv')

dfrm = df.groupby('room_type')['price'].agg(['mean', 'std', 'count'])
# Get the square root of the sample size
dfrm['sqrt_count'] = np.sqrt(dfrm['count'])

# get the standard devation of the mean
dfrm['std_of_mean'] = dfrm['std'] / dfrm['sqrt_count']

# two stds below the mean
dfrm['lower_bound'] = dfrm['mean'] - (2 *dfrm['std_of_mean'])

# two stds above the mean
dfrm['upper_bound'] = dfrm['mean'] + (2 *dfrm['std_of_mean'])
dfrm = dfrm.round()
dfrm
# Out:
#                   mean    std  count  sqrt_count  std_of_mean  lower_bound  \
# room_type
# Bungaloo           4.0    NaN      1         1.0          NaN          NaN
# Entire home/apt  199.0  338.0  23998       155.0          2.0        195.0
# Hotel room       275.0  302.0    398        20.0         15.0        245.0
# Penthouse        690.0    NaN      1         1.0          NaN          NaN
# Private room      91.0  282.0  21144       145.0          2.0         88.0
# Shared room       87.0  354.0    987        31.0         11.0         65.0
#
#                  upper_bound
# room_type
# Bungaloo                 NaN
# Entire home/apt        204.0
# Hotel room             305.0
# Penthouse                NaN
# Private room            95.0
# Shared room            110.0

# %%
# Import listings
df=pd.read_csv('data/listings.csv')

# %% [markdown]
# # Basic Analytics

# %% [markdown]
# ### Basic Inference
#
# 1. What do mean, standard deviation and standard deviation of the mean, ... mean(?)

# %% [markdown]
# #### Types of Mean
# 1.  arithmetic:  $\overline{a}_{\mathrm{ar}} = { \sum_{i=1}^{N} a_i \over N }$
# 2.  geometric:  $\overline{a}_{\mathrm{geo}} = \left( { \prod_{i=1}^{N} a_i  }\right)^{1 \over N}$
# 3.  harmonic:  $ { 1\over \overline{a}_{\mathrm{har}} } =  { \sum_{i=1}^{N} { 1 \over a_i} \over N } $

# %%
# Standard deviation of the mean 
# If we take an N sized sample, what will it look like?

# this generates a sample of normal data to serve as out population
mu, sigma = 0, 1 # mean and standard deviation
population = np.random.normal(mu, sigma, 10000)
plt.hist(population)
# Out:
# (array([  10.,   82.,  514., 1669., 2909., 2826., 1486.,  436.,   65.,
#            3.]),
#  array([-3.96794667, -3.16897076, -2.36999486, -1.57101896, -0.77204305,
#          0.02693285,  0.82590876,  1.62488466,  2.42386057,  3.22283647,
#          4.02181238]),
#  <BarContainer object of 10 artists>)

# %%
# repeatedly sample
import random 
sqrt_N = 10
N = sqrt_N*sqrt_N
mean_list = []
stdev_list = []


for i in range(1,1000):
    random.shuffle(population)
    sample = population[:N]
    # sample = np.random.normal(mu, sigma, N)
    mean_list.append(sample.mean())
    stdev_list.append(sample.std())

# %%
dfm = pd.DataFrame(mean_list, columns=['mean'])
dfm.plot.hist()

dfstd = pd.DataFrame(stdev_list, columns=['mean'])
dfstd.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### sample statistics
#
# * mean of the sample mean
# $$
# \mu_\mathrm{sm} \approx \mu_\mathrm{pop}
# $$
# * std of the mean:
# $$
# \sigma_\mathrm{sm}  \approx { \sigma_\mathrm{pop} \over \sqrt{N} }
# $$

# %%
np.mean(mean_list), np.std(mean_list) , 1/np.std(mean_list)
# Out:
# (-0.018124860023303102, 0.09676504620700943, 10.334310158450194)

# %% [markdown]
# # Tableau Prep

# %% [markdown]
# ### AirBnB Buroughs Map

# %%
#  We are going to make a map of all of the AirBNB properties. Later we do this in Tableau

cols_to_keep=['longitude','latitude']

crs={'init':'epsg:4326'}

boroughs = geopandas.read_file(geoplot.datasets.get_path('nyc_boroughs'))
geom = geopandas.points_from_xy(df["longitude"], df["latitude"])
geo_df=geopandas.GeoDataFrame(df, crs=crs,geometry=geom)

fig,ax=plt.subplots(figsize=(9,9))
fig.suptitle('Map of Listings, Colored by Borough', fontsize=20)
boroughs.plot(ax=ax,alpha=0.4,color="grey")
geo_df[geo_df['neighbourhood_group']=="Bronx"].plot(ax=ax,markersize=4, alpha=0.4,color="blue", label="Bronx")
geo_df[geo_df['neighbourhood_group']=="Manhattan"].plot(ax=ax,markersize=4, alpha=0.4,color="red", label="Manhattan")
geo_df[geo_df['neighbourhood_group']=="Queens"].plot(ax=ax,markersize=4, alpha=0.4,color="aqua", label="Queens")
geo_df[geo_df['neighbourhood_group']=="Brooklyn"].plot(ax=ax,markersize=4, alpha=0.4,color="orange", label="Brooklyn")
geo_df[geo_df['neighbourhood_group']=="Staten Island"].plot(ax=ax,markersize=4, alpha=0.4,color="green", label="Staten Island")
plt.legend()
# Out:
# c:\Users\yehtu\anaconda3\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# ### Histograms

# %%
# Now we make a set of price histograms

import matplotlib.pyplot as plt
import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

n_bins = 20

# price data to make histograms with

price_filter = df['price']<=500

neighborhood_filter = df['neighbourhood_group']=="Bronx"
bronx = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Brooklyn"
brooklyn = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Manhattan"
manhattan = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Queens"
queens = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Staten Island"
staten = df[neighborhood_filter & price_filter].price

fig, axs = plt.subplots(5, 1, sharey=True, sharex=True, tight_layout=True)

# sefault figsize is  6.4 X 4.8 inches.  we need someting taller
fig.set_size_inches(8, 12.0)

fig.suptitle('Price Histogram by Borough', fontsize=20)
# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(bronx, bins=n_bins, color = 'blue')
axs[1].hist(brooklyn, bins=n_bins, color = 'orange')
axs[2].hist(manhattan, bins=n_bins, color = 'red')
axs[3].hist(queens, bins=n_bins, color = 'aqua')
axs[4].hist(staten, bins=n_bins, color = 'green')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

# %%
df.plot(kind='hist', x='price', subplots=True )

cheap[['price', 'neighbourhood_group']].plot(kind='hist', subplots=True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 df.plot(kind='hist', x='price', subplots=True )
# ----> 3 cheap[['price', 'neighbourhood_group']].plot(kind='hist', subplots=True )
#
# NameError: name 'cheap' is not defined

# %%
cheap_df = df[df.price <= 500]
cheap_df.hist(
    column='price', 
    by='neighbourhood_group', 
    figsize=(5,13), 
    layout=(7,1), 
    sharex=True, 
    sharey=True
    )
# Out:
# array([<Axes: title={'center': 'Bronx'}>,
#        <Axes: title={'center': 'Brooklyn'}>,
#        <Axes: title={'center': 'Manhattan'}>,
#        <Axes: title={'center': 'Queens'}>,
#        <Axes: title={'center': 'Staten Island'}>, <Axes: >, <Axes: >],
#       dtype=object)

# %% [markdown]
# ### Box and Whisker

# %%
# Finally we make some "Box and Whisker"  Plots, using IQR for the boxes and whiskers

price_filter = (df['price']<=10000) &  (df['price']>=1)

neighborhood_filter = df['neighbourhood_group']=="Bronx"
bronx = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Brooklyn"
brooklyn = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Manhattan"
manhattan = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Queens"
queens = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Staten Island"
staten = df[neighborhood_filter & price_filter].price

box_weights = [bronx,brooklyn, manhattan, queens, staten]
labels = ['Bronx','Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
colors = ['blue', 'orange', 'red', 'aqua', 'green']
fig, ax = plt.subplots()

fig.set_size_inches(5, 7.0)

fig.suptitle('Box and Whisker', fontsize=20)
ax.set_ylabel('price')
ax.set_yscale('log')
bplot = ax.boxplot(box_weights,
                   patch_artist=True)  # will be used to label x-ticks
ax.set_xticklabels(labels) 
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

# %%
# in tableau, be sure to copy price and disaggregate it to match this plot
