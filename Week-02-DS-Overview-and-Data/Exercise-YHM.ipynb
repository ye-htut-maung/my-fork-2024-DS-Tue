# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
len(df_food)
# Out:
# 125

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
column_names = list(df_food.columns)

for column_name in column_names:
  print(f"name: {column_name}")
  print(f"type: {df_food[column_name].dtypes}\n")
# Out:
# name: GPA
# type: object
#
# name: Gender
# type: int64
#
# name: breakfast
# type: int64
#
# name: calories_chicken
# type: int64
#
# name: calories_day
# type: float64
#
# name: calories_scone
# type: float64
#
# name: coffee
# type: int64
#
# name: comfort_food
# type: object
#
# name: comfort_food_reasons
# type: object
#
# name: comfort_food_reasons_coded
# type: float64
#
# name: cook
# type: float64
#
# name: comfort_food_reasons_coded.1
# type: int64
#
# name: cuisine
# type: float64
#
# name: diet_current
# type: object
#
# name: diet_current_coded
# type: int64
#
# name: drink
# type: float64
#
# name: eating_changes
# type: object
#
# name: eating_changes_coded
# type: int64
#
# name: eating_changes_coded1
# type: int64
#
# name: eating_out
# type: int64
#
# name: employment
# type: float64
#
# name: ethnic_food
# type: int64
#
# name: exercise
# type: float64
#
# name: father_education
# type: float64
#
# name: father_profession
# type: object
#
# name: fav_cuisine
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
# Remove ‘em.
df_food_specific = df_food[["calories_day", "weight", "Gender"]]
df_food_specific
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
df_food_specific.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food_specific = df_food_specific.dropna()
df_food_specific
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
df_food_specific["weight"] = pd.to_numeric(df_food_specific["weight"],errors='coerce')
df_food_specific = df_food_specific.dropna()
df_food_specific
# Out:
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\1842126223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food_specific["weight"] = pd.to_numeric(df_food_specific["weight"],errors='coerce')
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
df_food_specific.to_csv("data/exported_new_food_coded.csv", index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).

df_salary = pd.read_csv("data/askamanagersalarysurvey2021(responses)-formresponses1.tsv", sep= "\t")
df_salary.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
len(df_salary)
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
df_salary.columns = ["timestamp", "age", "industry", "title", "title_context", "salary", "additional_compensation", "currency", "other_currency", "salary_context", "country", "state", "city", "total_yoe", "field_yoe", "highest_education_completed", "gender", "race"]

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   timestamp                    28062 non-null  object
#  1   age                          28062 non-null  object
#  2   industry                     27988 non-null  object
#  3   title                        28061 non-null  object
#  4   title_context                7262 non-null   object
#  5   salary                       28062 non-null  object
#  6   additional_compensation      20766 non-null  float64
#  7   currency                     28062 non-null  object
#  8   other_currency               208 non-null    object
#  9   salary_context               3043 non-null   object
#  10  country                      28062 non-null  object
#  11  state                        23039 non-null  object
#  12  city                         27984 non-null  object
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
print(df_salary["industry"].value_counts())
# Out:
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: industry, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# to get the name from value_counts
print(df_salary["industry"].value_counts().index[0:5].tolist())
# Out:
# ['Computing or Tech', 'Education (Higher Education)', 'Nonprofits', 'Health care', 'Government and Public Administration']

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
industry_top_5 = df_salary["industry"].value_counts().index[0:5].tolist()
df_salary_tech = df_salary[df_salary.industry.isin(industry_top_5)]
df_salary_tech.head()
# Out:
#             timestamp    age                      industry  \
# 0  4/27/2021 11:02:10  25-34  Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34             Computing or Tech
# 3  4/27/2021 11:02:41  25-34                    Nonprofits
# 5  4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8  4/27/2021 11:03:01  45-54             Computing or Tech
#
#                                       title                 title_context  \
# 0        Research and Instruction Librarian                           NaN
# 1  Change & Internal Communications Manager                           NaN
# 3                           Program Manager                           NaN
# 5            Scholarly Publishing Librarian                           NaN
# 8                           Systems Analyst  Data developer/ETL Developer
#
#     salary  additional_compensation currency other_currency salary_context  \
# 0   55,000                      0.0      USD            NaN            NaN
# ...

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

df_salary_tech.industry.value_counts()
# Out:
# Computing or Tech                       4699
# Education (Higher Education)            2464
# Nonprofits                              2419
# Health care                             1896
# Government and Public Administration    1889
# Name: industry, dtype: int64

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
currency_USD = df_salary_tech["currency"] == "USD"
df_salary_tech_USD = df_salary_tech[currency_USD]
df_salary_tech_USD.head()
# Out:
#              timestamp    age                      industry  \
# 0   4/27/2021 11:02:10  25-34  Education (Higher Education)
# 3   4/27/2021 11:02:41  25-34                    Nonprofits
# 5   4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8   4/27/2021 11:03:01  45-54             Computing or Tech
# 10  4/27/2021 11:03:03  25-34                    Nonprofits
#
#                                  title                 title_context   salary  \
# 0   Research and Instruction Librarian                           NaN   55,000
# 3                      Program Manager                           NaN   62,000
# 5       Scholarly Publishing Librarian                           NaN   62,000
# 8                      Systems Analyst  Data developer/ETL Developer  112,000
# 10                      Office Manager                           NaN   47,500
#
#     additional_compensation currency other_currency salary_context  \
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech_USD.country.value_counts()
# Out:
# United States     4318
# USA               3813
# US                1252
# U.S.               292
# United States      255
#                   ...
# Sri lanka            1
# Bangladesh           1
# United Statea        1
# Contracts            1
# Burma                1
# Name: country, Length: 139, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
fix_US_name_dict = {'United States': 'US', 'USA': 'US', 'U.S.': 'US', 'United States ' : 'US'}
df_salary_tech_USD["country"] = df_salary_tech_USD.country.replace(fix_US_name_dict)
# Out:
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\3504385557.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_USD["country"] = df_salary_tech_USD.country.replace(fix_US_name_dict)

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech_USD.country.value_counts()
# Out:
# US                          9930
# United States of America     222
# USA                          195
# Usa                          178
# usa                           81
#                             ...
#  US                            1
# Hartford                       1
# USS                            1
# Puerto Rico                    1
# Burma                          1
# Name: country, Length: 135, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
grouped_df_salary_tech_USD = df_salary_tech_USD.groupby('state')
salary_stats = grouped_df_salary_tech_USD['salary'].agg( ['min', 'mean', 'max'] )
sorted_salary_stats = salary_stats.sort_values(by='mean', ascending=False) 
sorted_salary_stats
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\yehtu\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File c:\Users\yehtu\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
df_salary_tech_USD.head()
# Out:
#              timestamp    age                      industry  \
# 0   4/27/2021 11:02:10  25-34  Education (Higher Education)
# 3   4/27/2021 11:02:41  25-34                    Nonprofits
# 5   4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8   4/27/2021 11:03:01  45-54             Computing or Tech
# 10  4/27/2021 11:03:03  25-34                    Nonprofits
#
#                                  title                 title_context   salary  \
# 0   Research and Instruction Librarian                           NaN   55,000
# 3                      Program Manager                           NaN   62,000
# 5       Scholarly Publishing Librarian                           NaN   62,000
# 8                      Systems Analyst  Data developer/ETL Developer  112,000
# 10                      Office Manager                           NaN   47,500
#
#     additional_compensation currency other_currency salary_context country  \
# ...

# %%
# Fix it.
df_salary_tech_USD["salary"] = df_salary_tech_USD["salary"].str.replace(',', '')
df_salary_tech_USD["salary"] = pd.to_numeric(df_salary_tech_USD["salary"],errors='coerce')
df_salary_tech_USD.head()
# Out:
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\357891975.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_USD["salary"] = df_salary_tech_USD["salary"].str.replace(',', '')
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\357891975.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_USD["salary"] = pd.to_numeric(df_salary_tech_USD["salary"],errors='coerce')
#              timestamp    age                      industry  \
# ...

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
grouped_df_salary_tech_USD = df_salary_tech_USD.groupby('state')
salary_stats = grouped_df_salary_tech_USD['salary'].agg( ['min', 'mean', 'max'] )
sorted_salary_stats = salary_stats.sort_values(by='mean', ascending=False) 
sorted_salary_stats
# Out:
#                                      min      mean     max
# state
# Michigan, Texas, Washington       340000  340000.0  340000
# Indiana, Ohio                     245000  245000.0  245000
# California, Colorado              176000  176000.0  176000
# Georgia, Massachusetts            175000  175000.0  175000
# Alabama, District of Columbia     156000  156000.0  156000
# ...                                  ...       ...     ...
# Michigan, South Carolina           51333   51333.0   51333
# Alabama, Oregon                    50000   50000.0   50000
# Maryland, Virginia                 48000   48000.0   48000
# Ohio, Washington                   43000   43000.0   43000
# District of Columbia, Washington   35000   35000.0   35000
#
# [81 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
df_salary_tech_USD.head()
# Out:
#              timestamp    age                      industry  \
# 0   4/27/2021 11:02:10  25-34  Education (Higher Education)
# 3   4/27/2021 11:02:41  25-34                    Nonprofits
# 5   4/27/2021 11:02:46  25-34  Education (Higher Education)
# 8   4/27/2021 11:03:01  45-54             Computing or Tech
# 10  4/27/2021 11:03:03  25-34                    Nonprofits
#
#                                  title                 title_context  salary  \
# 0   Research and Instruction Librarian                           NaN   55000
# 3                      Program Manager                           NaN   62000
# 5       Scholarly Publishing Librarian                           NaN   62000
# 8                      Systems Analyst  Data developer/ETL Developer  112000
# 10                      Office Manager                           NaN   47500
#
#     additional_compensation currency other_currency salary_context country  \
# ...

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_tech_USD["timestamp"] = pd.to_datetime(df_salary_tech_USD['timestamp'])
df_salary_tech_USD["year"] = df_salary_tech_USD['timestamp'].dt.strftime('%Y')
df_salary_tech_USD.head()
# Out:
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\1843890426.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_USD["timestamp"] = pd.to_datetime(df_salary_tech_USD['timestamp'])
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\1843890426.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_USD["year"] = df_salary_tech_USD['timestamp'].dt.strftime('%Y')
#              timestamp    age                      industry  \
# ...

# %%
print(df_salary_tech_USD.year.value_counts())
print(df_salary_tech_USD.year.dtype)
df_salary_tech_USD["year"] = df_salary_tech_USD.year.astype(int)
print(df_salary_tech_USD.year.dtype)
df_salary_tech_USD.year.value_counts()
# Out:
# 2021    10925
# 2022      113
# 2023       24
# 2024       22
# Name: year, dtype: int64
# object
# int32
# C:\Users\yehtu\AppData\Local\Temp\ipykernel_11436\610058793.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_USD["year"] = df_salary_tech_USD.year.astype(int)
# 2021    10925
# 2022      113
# 2023       24
# 2024       22
# Name: year, dtype: int64

# %%
filter_3_year = df_salary_tech_USD["year"].isin([2021, 2022, 2023])
df_final = df_salary_tech_USD[filter_3_year]
df_final.year.value_counts()
# Out:
# 2021    10925
# 2022      113
# 2023       24
# Name: year, dtype: int64

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
